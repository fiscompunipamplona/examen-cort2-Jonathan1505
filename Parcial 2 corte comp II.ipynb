# %% [markdown]
# ## DEPOSICION DE SUPERFICIE
# Varios procesos naturales y artificiales implican el depósito de partículas en una superficie para formar una película. Debido a que las partículas se evaporan típicamente de un filamento caliente, hay aleatoriedad en el proceso de emisión; sin embargo, las películas producidas resultan tener estructuras bien definidas (Figura 7.6).
#
# 1.Cree una simulación Monte Carlo de partículas que caen y se adhieren a una línea horizontal de longitud L compuesta de 200 sitios de deposición.
#
#
# a.Comience todas las partículas desde la misma altura.
#
# B. Simule las diferentes velocidades de emisión haciendo que las partículas caigan a distancias aleatorias a lo largo de la línea.
#
# C.Haga que una partícula se adhiera al sitio donde aterriza.
#
# D. Debido a que habrá columnas de partículas depuestas de varias alturas, la trayectoria de una partícula puede bloquearse antes de llegar a la línea, o puede rebotar entre columnas y luego caer en un agujero. Por lo tanto, suponga que si la altura de la columna a la que cae la partícula es mayor que la de sus dos vecinos, se agregará a esa altura.
#
# E.Si la partícula cae en un hoyo, o si hay un hoyo adyacente, llena el hoyo.
#
# F.Realice un diagrama continuo a medida que se deposita la superficie.
#
#
# 3.Extienda la simulación de deposición aleatoria a dos dimensiones, por lo que en lugar de hacer una línea de partículas, ahora depositamos una superficie completa. Realice un diagrama continuo a medida que se deposita la superficie.

# %%
from pylab import *
from random import *
N=10000
x=200
z=[]
a=[]
for i in range (N):
    z.append(randrange(0,x+1))
    
import random
l=[]
for i in range(N):
    r=random.uniform(0,x+1)
    l.append(r)
plot(l,z,'k.')
show()

# %% [markdown]
# # 2

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt

# Creamos la figura
fig = plt.figure()
# Creamos el plano 3D
ax1 = fig.add_subplot(111, projection='3d')
N=10000
x1=200
x=[]
zo=12
z=[]
for i in range (N):
    x.append(randrange(0,x1+1))
    
import random
y=[]
for i in range(N):
    r=random.uniform(0,x1+1)
    y.append(r)
    
for j in range(N):
    r=random.uniform(0,x1+1)
    z.append(r)
# Agregamos los puntos en el plano 3D
ax1.scatter(x, y, z, c='k', marker='.')
# Mostramos el gráfico
plt.show()
